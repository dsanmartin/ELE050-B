# %% [markdown]
# <a href="https://colab.research.google.com/github/dsanmartin/ELE050-B/blob/main/08_evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
from sklearn import svm
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV

# %% [markdown]
# # Datos

# %%
X, y = datasets.load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# # Modelo

# %%
model1 = svm.SVC(kernel='linear', C=1).fit(X_train, y_train)

# %%
model1.score(X_test, y_test), model1.score(X_train, y_train)
# Out:
# (1.0, 0.975)

# %% [markdown]
# # K-Fold cross validation

# %%
model_cv = svm.SVC(kernel='linear', C=1)
scores = cross_val_score(model_cv, X, y, cv=4)

# %%
scores.mean()
# Out:
# np.float64(0.9799075391180654)

# %% [markdown]
# # Ajuste de hiperparámetros

# %%
hyperparams_grid = [
    #'C': [1, 10, 100, 1000, 10000],
    #'kernel': ['linear', 'rbf', 'poly', 'sigmoid']
    {'C': [1, 10, 100, 1000, 10000], 'kernel': ['linear']},
    {'C': [1, 10, 100, 1000, 10000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']}
]

# %%
svc = svm.SVC()
grid_search = GridSearchCV(svc, hyperparams_grid, cv=4)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=SVC(),
#              param_grid=[{'C': [1, 10, 100, 1000, 10000], 'kernel': ['linear']},
#                          {'C': [1, 10, 100, 1000, 10000],
#                           'gamma': [0.001, 0.0001], 'kernel': ['rbf']}])

# %%
grid_search.best_score_, grid_search.best_params_
# Out:
# (np.float64(0.9583333333333334), {'C': 1, 'kernel': 'linear'})

# %%
grid_search.best_estimator_.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# ## Aleatorizado

# %%
random_grid_search = RandomizedSearchCV(svc, hyperparams_grid, cv=4)
random_grid_search.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=4, estimator=SVC(),
#                    param_distributions=[{'C': [1, 10, 100, 1000, 10000],
#                                          'kernel': ['linear']},
#                                         {'C': [1, 10, 100, 1000, 10000],
#                                          'gamma': [0.001, 0.0001],
#                                          'kernel': ['rbf']}])

# %%
random_grid_search.cv_results_['params']
# Out:
# [{'kernel': 'linear', 'C': 1000},
#  {'kernel': 'rbf', 'gamma': 0.0001, 'C': 10000},
#  {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1000},
#  {'kernel': 'linear', 'C': 10000},
#  {'kernel': 'rbf', 'gamma': 0.0001, 'C': 1},
#  {'kernel': 'linear', 'C': 100},
#  {'kernel': 'rbf', 'gamma': 0.0001, 'C': 100},
#  {'kernel': 'linear', 'C': 1},
#  {'kernel': 'rbf', 'gamma': 0.001, 'C': 10},
#  {'kernel': 'rbf', 'gamma': 0.001, 'C': 1}]

# %%
grid_search.cv_results_['params']
# Out:
# [{'C': 1, 'kernel': 'linear'},
#  {'C': 10, 'kernel': 'linear'},
#  {'C': 100, 'kernel': 'linear'},
#  {'C': 1000, 'kernel': 'linear'},
#  {'C': 10000, 'kernel': 'linear'},
#  {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'},
#  {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'},
#  {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'},
#  {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'},
#  {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'},
#  {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'},
#  {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'},
#  {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'},
#  {'C': 10000, 'gamma': 0.001, 'kernel': 'rbf'},
#  {'C': 10000, 'gamma': 0.0001, 'kernel': 'rbf'}]
